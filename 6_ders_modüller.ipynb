# %% [markdown]
# <a href="https://colab.research.google.com/github/MSaidKr/Python_Dersleri/blob/main/6_ders_mod%C3%BCller.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Math Modülü Uygulamaları**

# %%
import math

value = dir(math)
value = help(math)
value = math.sqrt(49)
value = math.factorial(4)
value = math.floor(5.9)
value = math.ceil(5.9) #ceil = tavan
print(value)
# Out:
# 6

# %%
import math as m

value = m.sqrt(49)
print(value)
# Out:
# 7.0

# %%
from math import *

value = factorial(5)
print(value)
# Out:
# 120

# %%
from math import sqrt,ceil as m

value = m(64)
print(value)
# Out:
# 8.0

# %%
from math import sqrt
def sqrt(a):
  return a + 4

value = sqrt(4)
print(value)
# Out:
# 8

# %%
def sqrt(a):
  return a + 4
from math import sqrt

value = sqrt(4)
print(value)
# Out:
# 2.0

# %% [markdown]
# # **Random Modülü**

# %%
import random

#result1 = dir(random)
#result = help(random)
#print(result1)
#print(result)
random.randint(1,2)
# Out:
# 2

# %%
insanlar = ['said','mehmet','eren','nisa','büşra']
random.shuffle(insanlar)
print(insanlar)
# Out:
# ['nisa', 'büşra', 'eren', 'mehmet', 'said']

# %%
sayılar = [1,5,4,3,2,6,8,7,9]
print(sayılar[random.randint(0,len(sayılar) - 1)])
# Out:
# 7

# %% [markdown]
# # **Yeni Modül Tanımlama**

# %%
# %%writefile mod.py
'''
burda modül var!
'''
print('modül eklendi')
number = 10
numbers = [1,2,3]

person1 = {
    "name":"ali",
    "age":"23",
    "city":"Eskisehir"
}
def func(x):
  '''
  fonksiyon var!
  '''
  print(f'x: {x}')

class Person:
  def speak(self):
    print("I am speaking")
# Out:
# Overwriting mod.py

# %%
import mod
import importlib
importlib.reload(mod) #kütüphaneyi güncel tut

mod.func(4)
adam = mod.person()
adam.speak()
#c = help(mod)
#c = help(mod.func)
c = mod.number
c = mod.numbers
#c = mod.__doc__
c = mod.person1["name"]
print(c)
# Out:
# modül eklendi
# x: 4
# I am speaking
# ali
