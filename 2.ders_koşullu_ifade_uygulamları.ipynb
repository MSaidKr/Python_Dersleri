# %% [markdown]
# <a href="https://colab.research.google.com/github/MSaidKr/Python_Dersleri/blob/main/ko%C5%9Fullu_ifade_uygulamlar%C4%B1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
isim = input("İsminizi Girin: ")
yas = int(input('yaş: '))
egitim = input('eğitim: ')
if (yas >= 18) and (egitim == 'lise' or egitim == 'üniversite'):
    print('ehliyet alabilirsiniz')
else:
    print('ehliyet alamazsınız')
# Out:
# İsminizi Girin: sadi
# yaş: 17
# eğitim: lise
# ehliyet alamazsınız

# %%
yazılı1 = int(input('yazılı1: '))
yazılı2 = int(input('yazılı2: '))
sozlu = int(input('sozlu: '))
ortalama = (yazılı1 + yazılı2 + sozlu) / 3
if ortalama >= 85 and ortalama <= 100:
    print('AA, helal lan yusufi')
elif ortalama >= 60 and ortalama <= 84:
    print('BB, iyi lan yusufi')
elif ortalama >= 40 and ortalama <= 59:
    print('CC, idare eder lan yusufi')
elif ortalama >= 0 and ortalama <= 39:
    print('FF, kaldın lan yusufi')
else :
    print('ğöğh')
# Out:
# yazılı1: 0
# yazılı2: 0
# sozlu: 0
# FF, kaldın lan yusufi

# %%
# 1.örnek
sayi = float(input('sayi: '))
if (sayi >= 0) and (sayi <= 100):
    print('sayı sıfır ile yüz arasında')
elif sayi < 0:
    print('sayı negatif')
else:
    print('sayı yüzden büyük')
# Out:
# sayi: 77
# sayı sıfır ile yüz arasında

# %%
# 1.örnek mark2
sayi = float(input('sayi: '))
result = (sayi >= 0) and (sayi <= 100)
if (result == True):
    print('sayı sıfır ile yüz arasında')
else:
    print('sayı sıfır ile yüz arasında değil')
# Out:
# sayi: 22
# sayı sıfır ile yüz arasında

# %%
# 2.örnek
sayi = float(input('sayi: '))
if (sayi > 0) and (sayi % 2 ==0):
  print ('sayı pozitif çift tam sayıdır')
else :
  print ('aradığımız sayı bu değil')
# Out:
# sayi: 33.2
# aradığımız sayı bu değil

# %%
# 3.örnek

email = 'msakraahmetoglu@gmail.com'
password = '12345'

girilenEmail = input('email: ')
girilenPassword = input('password: ')

if (girilenEmail == email) and (girilenPassword == password):
    print('giriş başarılı')
else:
    print('giriş başarısız')
# Out:
# email: saaslel
# password: dasda
# giriş başarısız

# %%
# 3.örnek mark2

email = 'mskaraahmetoglu@gmail.com'
password = '12345'

girilenEmail = input('email: ')
girilenEmail = girilenEmail.lower()
girilenPassword = input('password: ')

if (girilenEmail == email):
  if (girilenPassword == password):
    print('giriş başarılı')
  else:
    print('şifre yanlış')
else:
  print('email yanlış')
# Out:
# email: MSKARAAHMETOGLU@GMAIL.COM
# password: 12345
# giriş başarılı

# %%
a = int(input('a: '))
b = int(input('b: '))
c = int(input('c: '))

if a > b and a > c:
    print('a en büyük sayıdır')
elif b > a and b > c:
    print('b en büyük sayıdır')
elif c > a and c > b:
    print('c en büyük sayıdır')
# Out:
# a: 12
# b: 22
# c: 13
# b en büyük sayıdır

# %%
vize1 = int(input('vize1: '))
vize2 = int(input('vize2: '))
final = int(input('final: '))
ortalama = ((vize1 + vize2) / 2) * 0.6 + (final * 0.4)

if (ortalama>50) and (ortalama < 80):
  print('B')
elif (ortalama>80):
  print('A')
else:
  print('F')
# Out:
# vize1: 55
# vize2: 55
# final: 66
# B

# %%
name = input('name: ')
kg = float(input('kg: '))
hg = float(input('hg: '))
index = kg / (hg ** 2)
if (index > 0) and (index <= 18.4):
  print(f'{name} kilo indeksin: {index} ve değerledirmen zayif')
elif (index > 18.4) and (index <= 24.9):
  print(f'{name} kilo indeksin: {index} ve değerledirmen normal')
elif (index > 24.9) and (index <= 29.9):
  print(f'{name} kilo indeksin: {index} ve değerledirmen kilolu')
elif (index > 29.9) and (index <= 34.9):
  print(f'{name} kilo indeksin: {index} ve değerledirmen obez')
else:
  print('damn')
# Out:
# name: said
# kg: 80
# hg: 1.74
# said kilo indeksin: 26.42356982428326 ve değerledirmen kilolu
