# %% [markdown]
# <a href="https://colab.research.google.com/github/MSaidKr/Python_Dersleri/blob/main/string_methods.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
"""
x = input('sayı 1: ')
y = input('sayı 2: ')
toplam = int(x) + int(y)
print(toplam)
"""

#message = 'No its sasa lele. Not sale sale'
# message = message.upper() mesajı büyük yazar
# message = message.lower() mesajı küçük yazar
# message = message.title() ilk harfleri büyük yazar
# message = message.capitalize() sadece ilk harf büyük
# message = message.strip() baştaki ve sondaki boşlukları siler
# message = message.split() her kelimeyi tek tek böler
# message = message.split('.') text'i noktalardan böler
# message = ' '.join(message) harflerin arasına boşluk atar. Aynı zamanda başka karakterler için de kullanılabilir.
# ayırdığımız kelimleri birleştirmek için de kullanılır. örn:
# message = message.split()    (bize mesajın orijinal)
# message = ' '.join(message)     (halini verir)
# index = message.find('lele')
# print(index) bu iki kod bize aradığımız kelimenin indeksini verir.
# message.startwith('s') ... ile başlayan kelime
# message.endwith('e') ... ile biten kelime
# message = message.replace('sasa','dada') kelimeleri günceller
# message = message.center(100) ...karakter boşluğu içerisine yazıyı ortalar.

#print(message)

#userA = "said",1
#userB = ("ali",2 )
#userC = ("veli",3 )
#print(userA)
#print(userB)
#print(userC)

# Liste metotları ------------------------

#arabalar = ['bmw','mercedes','opel','mazda']
#result = len(arabalar)
#result = arabalar[2]
#result = arabalar[-2]
#arabalar[1]= 'toyota'
#result= arabalar[1]
#result = 'mercedes' in arabalar
#result = arabalar[0:4]
#result = arabalar[:4]
#result = arabalar + ['audi','nissan']
#result = arabalar * 2
#print(result)

# Liste metotları 2 -------------------

#numbers = [1,3,5,23,46,67,13,22]
#letters = ['a','g','r','b','s','d']
#val = min(numbers)
#print(val)
#val = max(numbers)
#print(val)
#val = sum(numbers) sum topluyorr
#print(val)
#val = min(letters)
#print(val)
#val = max(letters)
#print(val)

#numbers[4] = 40

#numbers.append(25) append metotu sona ekleme yapar

#numbers.insert(4,55) insert metotu istediğimiz indekse ekleme yapar

#numbers.pop() pop metotu sondaki elemanı siler

#numbers.pop(2) indeks verilirse o indeksteki elemanı siler

#numbers.remove(22) remove metotuna silmek istediğimiz eleman yazılır

#numbers.sort() elemanları küçülkten büyüğe sıralar

#numbers.reverse() elemanları ters sıralar

#print(numbers.count(22)) count metotu aradığımız elemanın sayısını verir

#numbers.clear() elemanları siler

#print(numbers)

# Liste metotları uygulamalar ------------------------

#names = ['ali','said','veli','ahmet','mustafa']
#years = [1998,2000,1998,1987]

#names.append('börü') yeni isim eklendi

#names.insert(2,'tarkan') # istediğimiz yere ismi eklemiş olduk

#names.remove('mustafa') istediğimiz ismi sildik

#names.pop(2) indeksteki ismi sildi

#said = names.index('said') istediğimiz ismin indeksini verir
#print( f'{said}hayatım bir numara')

#question = 'ali' in names
#print(question)

#names.reverse() ters çevirdik

#names.sort() alfabetik sıraya göre sıraladı

#years.sort() sayısal olarak küçükten büyüğe sıraladı
#print(years)

#str = 'dacia,chevrolet'
#result = str.split(',') bir stringi diziye çevirir
#print(result)

#min = min(years) minimum değeri verir
#print(min)
#max = max(years) maksimum değeri verir
#print(max)
#sum = sum(years) toplamı verir
#print(sum)

#result = years.count(1998) istediğimiz elemanın kaç tane olduğunu verir
#print(result)

#years.clear() diziyi siler
#print(years)

#markalar = []
#marka = input("marka: ")
#markalar.append(marka)
#print('1.marka eklendi')
#marka1 = input("marka: ")
#markalar.append(marka1)
#print('2.marka eklendi')
#marka2 = input("marka: ")
#markalar.append(marka2)
#print('3.marka eklendi')
#print(markalar)

#print(names)

#Tuple tipi listeler-------------------------

# list = [1,2,3]
# tuple = (1,'!',3)
# print(type(list))
# print(type(tuple))

# list = ['ali','veli']
# tuple = ('ayşe','damla')
# tuple[0]= 'sasa'
#yazdığımız üzere tuple listesinin üzerine yeni liste yazılabiliyor ancak sonradan herhangi bir atama yapılamıyor.
# tuple liste oluştururken köşesiz parantez kullanılır
# print(list)
# print(tuple)

# sehirler = ['istanbul','ankara','adana']
# plakalar = [34,6,1]
#print(plakalar[sehirler.index('istanbul')])

# plakalar = {'istanbul' : 34, 'rize' : 53}
# print(plakalar['rize'])

# plakalar['ankara'] = 6
# print(plakalar)

# users = {'sasa' : 20,
#          'lele' : 19}

# ogrenciler = {}

# number = input('öğrenci no: ')
# name = input('öğrenci adı: ')
# surname = input('öğrenci soyad: ')
# phone = input('öğrenci telefon: ')
# ogrenciler[number] = {
#     'ad' : name,
#     'soyad' : surname,
#     'telefon' : phone
# }
# print(ogrenciler)
#girilen bilgileri sql mantığı ile saklıyor.
# ogrenciler.update({
#     number : {
#         'ad' : name,
#         'soyad' : surname,
#         'telefon' : phone}
# })
#sonradan eleman ekleme işlemi

#python sets listeleri ---------------------------

# fruits = {'orange', 'apple', 'banana'}

# for x in fruits:
#     print(x)

# fruits.add('cherry')
# fruits.update(['mango','grape'])

# mylist = [1,2,5,4,4,5]
# print(set(mylist)) set metoduyla birlikte tekrarlanan elemanlar listeden paket edilir.

# fruits.remove('mango') mango paket
# fruits.pop() son eleman paket

# print(fruits)

#Bellek değerlendirmeleri---------------------------

x = 5
y = 34
z = 32
print(x is y)
print(x is z)
# Out:
# False
# False
